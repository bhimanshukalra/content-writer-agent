# %%
from __future__ import annotations

import operator
from typing import TypedDict, List, Annotated, Literal
from pathlib import Path

from pydantic import BaseModel, Field
from langgraph.graph import StateGraph, START, END
from langgraph.types import Send
import os
from langchain_groq import ChatGroq
from langchain_core.messages import SystemMessage, HumanMessage
from langchain_ollama import ChatOllama


import psycopg
from psycopg.rows import dict_row
from langgraph.checkpoint.postgres import PostgresSaver
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
def get_database_url():
    database_url = os.getenv("DATABASE_URL")

    if not database_url:
        raise ValueError(
            "DATABASE_URL is missing. Please add your Render PostgreSQL External Database URL to .env"
        )

    if "sslmode=" not in database_url:
        separator = "&" if "?" in database_url else "?"
        database_url = f"{database_url}{separator}sslmode=require"

    return database_url

# %%
class Task(BaseModel):
    id: int
    title: str

    goal: str = Field(
        ...,
        description="One sentence describing what the reader should be able to do/understand after this section.",
    )
    bullets: List[str] = Field(
        ...,
        min_length=3,
        max_length=5,
        description="3–5 concrete, non-overlapping subpoints to cover in this section.",
    )
    target_words: int = Field(
        ...,
        description="Target word count for this section (120–450).",
    )
    section_type: Literal[
        "intro", "core", "examples", "checklist", "common_mistakes", "conclusion"
    ] = Field(
        ...,
        description="Use 'common_mistakes' exactly once in the plan.",
    )

class Plan(BaseModel):
    blog_title: str
    audience: str = Field(..., description="Who this blog is for.")
    tone: str = Field(..., description="Writing tone (e.g., practical, crisp).")
    tasks: List[Task]

class State(TypedDict):
    topic: str
    plan: Plan
    sections: Annotated[List[str], operator.add]  # reducer concatenates worker outputs
    final: str

# %%
llm = ChatOllama(
    model="llama3.1:8b"
)

# %%
def orchestrator(state: State) -> dict:
    planner = llm.with_structured_output(Plan)

    plan = planner.invoke(
        [
            SystemMessage(
                content=(
                    "You are a senior technical writer and developer advocate. Your job is to produce a "
                    "highly actionable outline for a technical blog post.\n\n"
                    "Hard requirements:\n"
                    "- Create 5–7 sections (tasks) that fit a technical blog.\n"
                    "- Each section must include:\n"
                    "  1) goal (1 sentence: what the reader can do/understand after the section)\n"
                    "  2) 3–5 bullets that are concrete, specific, and non-overlapping\n"
                    "  3) target word count (120–450)\n"
                    "- Include EXACTLY ONE section with section_type='common_mistakes'.\n\n"
                    "Make it technical (not generic):\n"
                    "- Assume the reader is a developer; use correct terminology.\n"
                    "- Prefer design/engineering structure: problem → intuition → approach → implementation → "
                    "trade-offs → testing/observability → conclusion.\n"
                    "- Bullets must be actionable and testable (e.g., 'Show a minimal code snippet for X', "
                    "'Explain why Y fails under Z condition', 'Add a checklist for production readiness').\n"
                    "- Explicitly include at least ONE of the following somewhere in the plan (as bullets):\n"
                    "  * a minimal working example (MWE) or code sketch\n"
                    "  * edge cases / failure modes\n"
                    "  * performance/cost considerations\n"
                    "  * security/privacy considerations (if relevant)\n"
                    "  * debugging tips / observability (logs, metrics, traces)\n"
                    "- Avoid vague bullets like 'Explain X' or 'Discuss Y'. Every bullet should state what "
                    "to build/compare/measure/verify.\n\n"
                    "Ordering guidance:\n"
                    "- Start with a crisp intro and problem framing.\n"
                    "- Build core concepts before advanced details.\n"
                    "- Include one section for common mistakes and how to avoid them.\n"
                    "- End with a practical summary/checklist and next steps.\n\n"
                    "Output must strictly match the Plan schema."
                )
            ),
            HumanMessage(content=f"Topic: {state['topic']}"),
        ]
    )

    return {"plan": plan}

# %%
def fanout(state: State):
    return [
        Send(
            "worker",
            {"task": task, "topic": state["topic"], "plan": state["plan"]},
        )
        for task in state["plan"].tasks
    ]

# %%
def worker(payload: dict) -> dict:

    task = payload["task"]
    topic = payload["topic"]
    plan = payload["plan"]

    bullets_text = "\n- " + "\n- ".join(task.bullets)

    section_md = llm.invoke(
        [
            SystemMessage(
    content=(
        "You are a senior technical writer and developer advocate. Write ONE section of a technical blog post in Markdown.\n\n"
        "Hard constraints:\n"
        "- Follow the provided Goal and cover ALL Bullets in order (do not skip or merge bullets).\n"
        "- Stay close to the Target words (±15%).\n"
        "- Output ONLY the section content in Markdown (no blog title H1, no extra commentary).\n\n"
        "Technical quality bar:\n"
        "- Be precise and implementation-oriented (developers should be able to apply it).\n"
        "- Prefer concrete details over abstractions: APIs, data structures, protocols, and exact terms.\n"
        "- When relevant, include at least one of:\n"
        "  * a small code snippet (minimal, correct, and idiomatic)\n"
        "  * a tiny example input/output\n"
        "  * a checklist of steps\n"
        "  * a diagram described in text (e.g., 'Flow: A -> B -> C')\n"
        "- Explain trade-offs briefly (performance, cost, complexity, reliability).\n"
        "- Call out edge cases / failure modes and what to do about them.\n"
        "- If you mention a best practice, add the 'why' in one sentence.\n\n"
        "Markdown style:\n"
        "- Start with a '## <Section Title>' heading.\n"
        "- Use short paragraphs, bullet lists where helpful, and code fences for code.\n"
        "- Avoid fluff. Avoid marketing language.\n"
        "- If you include code, keep it focused on the bullet being addressed.\n"
    )
)
,
            HumanMessage(
                content=(
                    f"Blog: {plan.blog_title}\n"
                    f"Audience: {plan.audience}\n"
                    f"Tone: {plan.tone}\n"
                    f"Topic: {topic}\n\n"
                    f"Section: {task.title}\n"
                    f"Section type: {task.section_type}\n"
                    f"Goal: {task.goal}\n"
                    f"Target words: {task.target_words}\n"
                    f"Bullets:{bullets_text}\n"
                )
            ),
        ]
    ).content.strip()

    return {"sections": [section_md]}

# %%
def reducer(state: State) -> dict:

    title = state["plan"].blog_title
    body = "\n\n".join(state["sections"]).strip()
    
    final_md = f"# {title}\n\n{body}\n"

    # Save to file
    filename = "".join(c if c.isalnum() or c in (" ", "_", "-") else "" for c in title)
    filename = filename.strip().lower().replace(" ", "_") + ".md"
    Path(filename).write_text(final_md, encoding="utf-8")

    return {"final": final_md}

# %%
state_graph = StateGraph(State)
state_graph.add_node("orchestrator", orchestrator)
state_graph.add_node("worker", worker)
state_graph.add_node("reducer", reducer)

state_graph.add_edge(START, "orchestrator")
state_graph.add_conditional_edges("orchestrator", fanout, ["worker"])
state_graph.add_edge("worker", "reducer")
state_graph.add_edge("reducer", END)

# %%
DATABASE_URL = get_database_url()

_conn = psycopg.connect(
    DATABASE_URL,
    autocommit=True,
    row_factory=dict_row
)

checkpointer = PostgresSaver(_conn)
checkpointer.setup()

# %%
app = state_graph.compile(checkpointer=checkpointer)

app

# %%
config = {
        "configurable": {
            "thread_id": "test_thread_id"
        }
    }

# %%
out = app.invoke({"topic": "Write a blog on Self Attention", "sections": []}, config=config)
# Out:
# Deserializing unregistered type __main__.Plan from checkpoint. This will be blocked in a future version. Set LANGGRAPH_STRICT_MSGPACK=true to block now, or add to allowed_msgpack_modules to allow explicitly: [('__main__', 'Plan')]

# %%
out
# Out:
# {'topic': 'Write a blog on Self Attention',
#  'plan': Plan(blog_title='Demystifying Self-Attention: A Technical Guide to Implementing Transformers', audience='NLP developers', tone='Technical', tasks=[Task(id=1, title='Problem Framing and Intuition', goal='Understand the problem and intuition behind self-attention and Transformers', bullets=['Describe the limitations of traditional sequence models (e.g., RNNs, CNNs) and the need for parallelization', 'Explain the key insight behind self-attention: capturing long-range dependencies without sequential processing', 'Highlight the role of multi-head attention in enhancing representational capacity and adaptability'], target_words=150, section_type='intro'), Task(id=2, title='Self-Attention Mechanism', goal='Understand the self-attention mechanism and its components', bullets=['Show a minimal code snippet for computing attention weights using dot-product and softmax', 'Explain why matrix multiplication is used to compute attention weights and query-key similarities', 'Highlight the importance of the scaling factor in the attention mechanism'], target_words=200, section_type='core'), Task(id=3, title='Common Mistakes: Understanding Self-Attention', goal='Learn how to avoid common mistakes when implementing self-attention', bullets=['Explain why using a small embedding size can lead to underutilization of attention weights', 'Highlight the importance of padding and positional encoding in self-attention', 'Show an example of how to use masking to prevent attention on padding tokens'], target_words=250, section_type='common_mistakes'), Task(id=4, title='Multi-Head Attention', goal='Understand the implementation and benefits of multi-head attention', bullets=['Show a code snippet for computing multi-head attention using multiple attention mechanisms', 'Explain how multi-head attention improves representational capacity and adaptability', 'Highlight the importance of hyperparameter tuning for multi-head attention'], target_words=250, section_type='core'), Task(id=5, title='Edge Cases and Failure Modes', goal='Understand how to handle edge cases and failure modes in self-attention', bullets=['Explain why out-of-vocabulary words can cause attention weights to go to zero', 'Highlight the importance of using a vocabulary and subwording', 'Show an example of how to handle out-of-vocabulary words using subwording'], target_words=200, section_type='core'), Task(id=6, title='Implementation and Testing', goal='Understand how to implement and test self-attention in a real-world scenario', bullets=['Show a code snippet for implementing self-attention in PyTorch or TensorFlow', 'Explain how to measure and visualize attention weights for interpretability', 'Highlight the importance of using a metrics library for evaluation and monitoring'], target_words=300, section_type='core'), Task(id=7, title='Conclusion and Next Steps', goal='Summarize key takeaways and provide next steps for implementing self-attention', bullets=['Summarize the key components and benefits of self-attention', 'Highlight the importance of continued research and experimentation', 'Provide resources for further learning and implementation'], target_words=100, section_type='conclusion')]),
#  'sections': ['## Introduction to Self-Attention\nIn this blog post, we will explore the concept of self-attention and its significance in personal growth and development. We will discuss how self-attention can help individuals focus on their goals, improve their productivity, and enhance their overall well-being.',
#   "### Understanding Self-Attention\n==============================\n\nSelf-attention is often misunderstood as being synonymous with self-regulation and self-awareness. However, while these concepts are interconnected, they each have distinct meanings and functions.\n\nSelf-awareness is the ability to have an accurate perception of oneself, including one's strengths, weaknesses, and emotions. Self-regulation, on the other hand, is the ability to control and regulate one's thoughts, feelings, and behaviors.\n\nSelf-attention, in contrast, is the act of focusing one's attention inward, on the self. It involves turning the spotlight of awareness onto one's internal experiences, thoughts, and emotions, without judgment or attachment. By cultivating self-attention, individuals can develop a greater understanding of themselves, including their motivations, desires, and values. This increased self-awareness can lead to greater personal growth, as individuals are better equipped to make intentional choices that align with their goals and values.",
#   "### Benefits of Self-Attention\n\nSelf-attention has numerous benefits for individuals, including:\n\n*   **Improved Focus**: By directing your attention inward, you can quiet the mind and develop a greater sense of clarity and purpose. This clarity enables you to focus on what's truly important and make decisions that align with your values.\n*   **Increased Productivity**: When you cultivate self-attention, you become more aware of your thoughts, emotions, and behaviors. This increased awareness allows you to identify areas where you can optimize your time and energy, leading to greater productivity and efficiency.\n*   **Enhanced Creativity**: Self-attention can help you tap into your inner source of creativity. By quieting the mind and accessing your inner wisdom, you can generate new ideas, solve problems, and approach challenges with a fresh perspective.\n*   **More Positive and Resilient Mindset**: Self-attention allows you to develop a greater sense of self-awareness and self-acceptance. This leads to a more positive and resilient mindset, enabling you to better handle challenges and maintain a sense of calm and well-being in the face of adversity.",
#   '### Techniques for Cultivating Self-Attention\n\nDeveloping self-attention is a skill that can be cultivated through various techniques. Here are a few practical methods to help you tap into your inner awareness:\n\n#### Mindfulness\n\n*   Practice mindfulness meditation by focusing on your breath, body sensations, or sensory experiences.\n*   Engage in mindfulness exercises, such as walking or eating, to cultivate present-moment awareness.\n*   Pay attention to your thoughts, emotions, and physical sensations without judgment.\n\n#### Journaling\n\n*   Set aside time each day to reflect on your experiences, thoughts, and emotions.\n*   Write down your goals, aspirations, and intentions to clarify your priorities.\n*   Regularly review your journal entries to track progress and identify areas for improvement.\n\n#### Intention Setting\n\n*   Establish clear, specific, and achievable goals for yourself.\n*   Focus on one goal at a time, breaking it down into smaller, manageable steps.\n*   Regularly review and adjust your goals to ensure they align with your values and priorities.\n\nBy incorporating these techniques into your daily routine, you can cultivate self-attention, unlock your full potential, and achieve your personal goals.',
#   '### Overcoming Challenges and Staying Committed\n\nCultivating self-attention requires dedication and perseverance, but it\'s not uncommon for individuals to encounter challenges along the way. Two common obstacles are distractions and self-doubt.\n\n#### Distractions\n\nIn today\'s fast-paced world, distractions are plentiful. Social media, email, and text notifications can all compete for our attention, making it difficult to focus on our inner world. To overcome distractions, try these strategies:\n\n*   Schedule dedicated time for self-attention practice\n*   Find a quiet, distraction-free space for practice\n*   Set boundaries with others to protect your practice time\n*   Use technology to your advantage, such as apps that help you stay focused\n\n#### Self-Doubt\n\nSelf-doubt can be a significant barrier to self-attention practice. You may wonder if you\'re doing it "right," or if you\'re good enough. To overcome self-doubt:\n\n*   Be kind and compassionate with yourself\n*   Celebrate small victories, no matter how insignificant they may seem\n*   Seek guidance from a qualified teacher or mentor\n*   Focus on the process, rather than the outcome',
#   "### Conclusion: Unlocking Your Full Potential\n\nIn conclusion, self-attention is a powerful tool for personal growth and development. By cultivating self-awareness, acknowledging and addressing our weaknesses, and focusing on our strengths, we can unlock our full potential and achieve our goals. We encourage you to start your self-attention journey today and discover the transformative power of self-awareness. Remember, it's time to shine your light and unlock your full potential.",
#   "Final Thoughts and Call to Action\n================================\n\nAs you embark on this transformative journey of cultivating self-attention, remember that it's a process that takes time, patience, and compassion. Be gentle with yourself as you learn to tune into your inner voice and prioritize your needs.\n\nRemember, self-attention is not about selfishness, but about being present and aware of what truly matters to you. By focusing on your own well-being and growth, you'll become a more effective and empathetic individual, better equipped to serve others.\n\nWe encourage you to share your experiences and insights with us as you cultivate self-attention. What tips and strategies have worked for you? How has your perspective on life and relationships changed since starting this journey?\n\nLet's connect and support one another in our pursuit of greater self-awareness and understanding. Share your stories, ask questions, and learn from others who are on this path with you.\n\nJoin the conversation and let's rise together, empowered by our growing understanding of the transformative power of self-attention.",
#   '### Introduction\n\nTucked away in the southeastern region of Japan lies the enigmatic town of Mokobara. This charming beachside community has long been a source of fascination for travelers and locals alike, with its rich history, breathtaking natural scenery, and unique cultural heritage. For those seeking an authentic Japanese experience, Mokobara is an absolute must-visit destination. In this comprehensive guide, we will delve into the secrets of Mokobara, exploring its history, attractions, and the best ways to experience all this hidden gem has to offer.',
#   "### History\n\nMokobara, a small beachside town in Japan, has a rich and storied history that dates back to the 17th century. The area was first settled by the Abe family, who were samurai from the Matsubara region. In the early 1600s, the Abe family established a small fishing village, which would eventually grow into the thriving town of Mokobara.\n\nDuring the Edo period (1603-1867), Mokobara became an important center for salt production, with the town's residents harvesting salt from the sea and selling it to markets throughout the region. The town's strategic location on the coast made it an ideal spot for trade and commerce, and Mokobara quickly became a hub of economic activity.\n\nIn the late 19th century, Mokobara underwent significant changes with the arrival of the railway. The town's proximity to the port city of Kobe and its access to the railway network made it an attractive location for businesses and industries. The town's economy continued to grow, and Mokobara became a major producer of textiles, ceramics, and other goods.\n\nToday, Mokobara remains a charming and historic beachside town, with a deep sense of community and tradition. The town's residents take great pride in their heritage, and visitors can experience the town's rich history and culture by exploring its historic buildings, temples, and museums.",
#   "### Geography and Climate\n\nMokobara is a picturesque beachside town located in the southern part of Wakayama Prefecture on the Kii Peninsula in Japan. This tranquil town is nestled between the Pacific Ocean and the towering Kii Mountains, creating a unique and breathtaking landscape.\n\n**Geographical Location**\nMokobara is situated approximately 10 kilometers north of Wakayama City, the capital of Wakayama Prefecture. The town's proximity to the ocean and the surrounding mountains makes it an attractive destination for nature lovers and those seeking a peaceful retreat from the hustle and bustle of city life.\n\n**Climate**\nMokobara's climate is characterized by mild winters and hot, humid summers. The average temperature ranges from 3°C (37°F) in January, the coldest month, to 28°C (82°F) in August, the warmest month. The town experiences a significant amount of rainfall throughout the year, with the majority of it falling between June and September. This lush climate supports the growth of a diverse range of flora, including lush forests, verdant hills, and vibrant wildflowers.\n\n**Natural Features**\nMokobara is renowned for its stunning natural beauty, with crystal-clear waters, white sandy beaches, and rocky coastlines. The town's coastline is dotted with scenic lookout points, perfect for taking in the breathtaking views of the ocean and surrounding landscape. The nearby mountains offer a range of hiking trails, providing visitors with the opportunity to explore the region's unspoiled wilderness and enjoy the majestic scenery.",
#   "**Cultural Significance**\n=======================\n\nMokobara's cultural significance extends far beyond its picturesque beaches and tranquil atmosphere. The town has a rich cultural heritage, shaped by its unique history and geography. Here, we delve into the customs, traditions, and festivals that make Mokobara a fascinating destination for cultural enthusiasts.\n\n### History and Influences\n\nMokobara's history is marked by its strategic location, which has made it a crossroads for various cultures. The town's proximity to the sea has facilitated trade and cultural exchange with neighboring islands and mainland Japan. Over time, this has resulted in a unique blend of traditions, with influences from both Japanese and foreign cultures.\n\n### Customs and Traditions\n\nMokobara's residents take great pride in their customs and traditions, which are deeply rooted in their daily lives. Some of the most notable customs include:\n\n*   **The Festival of the Full Moon**: A traditional festival celebrated annually during the full moon, where locals gather to honor the gods and enjoy traditional music, dance, and food.\n*   **The Beachside Bon Festival**: A unique variation of the traditional Bon Festival, where locals honor their ancestors by releasing paper lanterns onto the sea.\n*   **The Mokobara Tea Ceremony**: A traditional tea ceremony, where locals gather to enjoy matcha and traditional sweets in a serene and tranquil atmosphere.\n\n### Modern Cultural Developments\n\nIn recent years, Mokobara has seen a resurgence of interest in its cultural heritage, with efforts to preserve and promote its customs and traditions. The town has established various cultural institutions, including museums, art galleries, and traditional craft workshops, which offer visitors a glimpse into its rich cultural past.\n\n### Conclusion\n\nMokobara's cultural significance is a testament to its unique history and geography. From its traditional customs and festivals to its modern cultural developments, the town offers a fascinating blend of old and new. Whether you're interested in history, culture, or simply want to experience a tranquil and picturesque beachside town, Mokobara has something to offer.",
#   "### Things to Do\n\nExplore Mokobara's tranquil atmosphere and rich culture by engaging in the following activities and visiting its notable attractions:\n\n*   Visit the Mokobara Beach, known for its picturesque sunsets and calm waters.\n*   Take a stroll along the Mokobara Coastline Trail, offering breathtaking views of the surrounding landscape.\n*   Learn about the town's history and culture at the Mokobara Museum.\n*   Try traditional Japanese cuisine at one of the local restaurants, serving fresh seafood and local specialties.\n*   Attend a traditional tea ceremony or participate in a Japanese art workshop to experience the town's unique culture.\n*   Visit the nearby Mokobara Lighthouse, offering panoramic views of the coastline.\n*   Take a boat tour to explore the nearby islands and coral reefs.",
#   "### Cuisine\n\nMokobara's culinary scene is a reflection of its Japanese heritage and coastal location. The town offers a range of traditional and local dishes that showcase the freshest seafood and seasonal ingredients. Here are some must-try cuisine options in Mokobara:\n\n* **Sushi and Sashimi**: Fresh seafood is a staple in Mokobara, and sushi and sashimi are a must-try. Visit local restaurants for a taste of the freshest fish, carefully prepared by skilled chefs.\n* **Yakitori**: Grilled chicken skewers are a popular street food in Japan, and Mokobara is no exception. Enjoy yakitori at local bars and restaurants for a flavorful and aromatic experience.\n* **Tonkatsu**: A breaded and deep-fried pork cutlet, tonkatsu is a beloved Japanese dish. Mokobara's restaurants serve tonkatsu with a side of shredded cabbage and a drizzle of tangy sauce.\n* **Seafood Tempura**: Mokobara's coastal location makes it an ideal place to try seafood tempura. Fresh seafood is lightly battered and deep-fried to perfection, served with a side of dipping sauce.\n* **Local Sweets**: Mokobara is famous for its local sweets, such as matcha ice cream and mochi. Visit local shops and cafes to try these delicious treats and take a piece of Mokobara's charm back home.",
#   "### Conclusion\n\nIn conclusion, Mokobara is a hidden gem that deserves more attention from travelers and beach enthusiasts. Its tranquil atmosphere, stunning beaches, and rich cultural heritage make it an ideal destination for those seeking a serene and authentic Japanese experience. By understanding and respecting the local customs and traditions, visitors can truly unlock the secrets of Mokobara and make the most of their stay. Whether you're looking for a relaxing getaway or an opportunity to immerse yourself in Japanese culture, Mokobara is a destination that will leave you feeling refreshed and inspired.",
#   '**Introduction to Mokobara**\n==========================\n\nLocated in the heart of [region], Mokobara is a hidden gem that offers a unique blend of natural beauty and adventure. Nestled in a serene landscape, this enchanting destination is a haven for nature lovers, outdoor enthusiasts, and those seeking solace in the great outdoors. With its diverse flora and fauna, Mokobara is a treasure trove of experiences waiting to be uncovered.',
#   "### The Natural Beauty of Mokobara\n\nMokobara is a treasure trove of natural beauty, boasting a diverse array of landscapes that cater to different tastes and preferences. The area is characterized by lush green forests, rolling hills, and winding streams that meander through the terrain. One of the most striking features of Mokobara is its unique rock formations, which have been shaped by the forces of nature over millions of years. The landscape is dotted with granite boulders, sandstone cliffs, and rugged outcrops that offer a glimpse into the region's geological history.\n\nThe forests of Mokobara are home to a wide variety of flora and fauna, including several species of trees, plants, and animals that are found nowhere else in the world. The area is particularly famous for its bamboo forests, which stretch as far as the eye can see and create a surreal landscape that is both mystical and awe-inspiring. The forests are also home to a diverse range of wildlife, including birds, monkeys, and other small animals that roam freely in the area.\n\nIn addition to its natural beauty, Mokobara is also known for its serene and tranquil atmosphere, which makes it an ideal destination for those seeking to escape the stresses of modern life. The area is particularly popular among nature lovers, adventure seekers, and those looking for a peaceful retreat from the hustle and bustle of city life.",
#   "### Outdoor Activities and Adventures\n#### Hike and Explore\nMokobara offers a network of trails that cater to all levels of hikers, from leisurely strolls to challenging ascents. Explore the lush forests, discover hidden waterfalls, and take in the breathtaking views of the surrounding landscape.\n\n#### Rock Climbing and Bouldering\nFor the adventurous, Mokobara's rugged terrain provides a paradise for rock climbers and boulderers. Scale the rocky outcroppings, test your limits, and experience the thrill of conquering new heights.\n\n#### Water Sports and Activities\nThe picturesque lakes and rivers of Mokobara offer a range of water sports and activities, including kayaking, canoeing, and fishing. Relax on the calm waters or get your adrenaline pumping with a whitewater rafting experience.\n\n#### Wildlife Watching and Birding\nMokobara is a haven for wildlife enthusiasts, with an incredible array of flora and fauna to discover. Spot exotic birds, deer, and other wildlife as you explore the natural beauty of the area.\n\n#### Cycling and Mountain Biking\nWith its scenic trails and varied terrain, Mokobara is a cyclist's paradise. Ride through the forests, climb the hills, and experience the thrill of mountain biking in a stunning natural setting.",
#   "### Cultural Significance and History\n\nMokobara, a remote island located in the Pacific, has a rich cultural heritage and a complex history. The island was initially inhabited by the ancient Polynesian people who arrived there around the 13th century. The island's strategic location made it an ideal spot for navigation and trade, with many ancient navigators using it as a stopping point between Hawaii and New Zealand.\n\nThe island's unique culture was heavily influenced by its geographical isolation. The native inhabitants developed a distinct language, customs, and traditions that were shaped by their surroundings. The island's lush forests, rugged coastlines, and coral reefs created a harsh yet beautiful environment that taught the inhabitants the importance of living in harmony with nature.\n\nIn the late 19th century, Mokobara was colonized by European powers, which had a profound impact on the island's culture. The introduction of foreign languages, customs, and religions led to the decline of the native culture, and many of the island's traditional practices were lost.\n\nDespite the challenges it faced, Mokobara's cultural significance remains strong. The island is home to many ancient archaeological sites, including a 1,000-year-old temple that is still used for spiritual purposes today. The island's unique culture and history have also attracted tourists and researchers from around the world, who come to experience the island's natural beauty and rich cultural heritage.",
#   "### Tips and Essentials for Visiting Mokobara\n\n#### Traveling to Mokobara\n\n*   **Getting There**: Mokobara can be reached by air or land. The nearest airport is [Airport Name], and from there, you can take a taxi or bus to the town of [Town Name].\n*   **Transportation**: The best way to explore Mokobara is by renting a car or hiring a local guide. This will give you the flexibility to explore the area at your own pace.\n\n#### Accommodation\n\n*   **Types of Accommodation**: Mokobara offers a range of accommodation options, from budget-friendly guesthouses to luxury resorts.\n*   **Booking**: It's recommended to book your accommodation in advance, especially during peak season.\n\n#### Safety and Precautions\n\n*   **Weather**: Mokobara has a tropical climate, with high temperatures and humidity levels throughout the year. Be sure to bring sunscreen, hats, and light clothing.\n*   **Responsible Tourism**: Mokobara is a fragile ecosystem. Be sure to respect the local environment and wildlife, and avoid littering or damaging the natural habitats.\n\n#### Essential Gear and Equipment\n\n*   **Clothing**: Pack light, breathable clothing and comfortable shoes for hiking and exploring.\n*   **Sunscreen and Insect Repellent**: Don't forget to bring sunscreen and insect repellent to protect yourself from the sun and insects.\n*   **Water Bottle**: Stay hydrated by bringing a refillable water bottle.",
#   "### Personal Experience and Recommendations\n\nAs I stepped into the lush forests of Mokobara, I couldn't help but feel a sense of awe and wonder. This hidden gem of a destination has left an indelible mark on my heart. Here's a personal account of my experience and some recommendations for future visitors.\n\n**My Experience**\n\nI spent three days exploring the breathtaking landscapes of Mokobara, and each day was a new adventure. I hiked through the dense forests, climbed the rugged hills, and even took a dip in the crystal-clear waters. The experience was nothing short of exhilarating, and I felt rejuvenated and refreshed by the end of it.\n\n**Recommendations**\n\nIf you're planning a visit to Mokobara, here are a few recommendations to make the most of your trip:\n\n*   **Hike to the summit**: The views from the top are nothing short of breathtaking, and the sense of accomplishment is unparalleled.\n*   **Take a dip in the waterfalls**: The crystal-clear waters are perfect for a refreshing dip on a hot day.\n*   **Stay overnight in the forest**: The night skies are a sight to behold, and waking up to the sounds of nature is an experience like no other.\n*   **Respect the environment**: Mokobara is a fragile ecosystem, and it's essential to respect the environment and follow the rules to preserve it for future generations.\n\nWhether you're an adventure-seeker or just looking for a peaceful retreat, Mokobara has something to offer everyone. So pack your bags, grab your hiking boots, and get ready to experience the natural beauty of this hidden gem.",
#   "### Conclusion and Final Thoughts\n\nIn conclusion, Mokobara is a hidden gem that offers a unique blend of natural beauty and adventure. From its stunning beaches to its lush forests and crystal-clear waters, this destination is a nature lover's paradise. Whether you're looking to relax and unwind or explore and discover, Mokobara has something for everyone. We hope this blog post has inspired you to visit Mokobara and experience its beauty for yourself.",
#   "**The Power of Self-Attention: Unlocking Your Full Potential**\n===========================================================\n\n### Introduction\n\nIn today's fast-paced world, it's easy to get caught up in the hustle and bustle of daily life and lose sight of what's truly important. We often find ourselves struggling to stay focused, juggling multiple tasks at once, and neglecting our own needs in the process. But what if you could tap into a powerful force that would allow you to stay focused, motivated, and in control, no matter what life throws your way? Enter the concept of self-attention. In this blog, we'll explore the importance of self-attention and how it can help you unlock your full potential.",
#   "## What is Self-Attention?\n\nSelf-attention is a psychological concept that refers to the ability to focus one's attention inward, towards one's own thoughts, feelings, and experiences. It involves being aware of and attending to one's internal states, such as emotions, physical sensations, and mental images. Self-attention is essential for personal growth, self-awareness, and making intentional decisions.\n\nIn essence, self-attention is about cultivating a sense of inner awareness, where you can tune into your own needs, desires, and values. It's about being present in the moment and acknowledging your internal experiences without judgment or distraction. By practicing self-attention, you can develop a deeper understanding of yourself, your motivations, and your behaviors, allowing you to make more informed choices and live a more authentic life.",
#   "### Benefits of Self-Attention\nSelf-attention has numerous benefits that can be observed in both personal and professional life. Some of the key advantages include:\n\n*   **Improved Focus**: By prioritizing self-attention, individuals can develop a clear sense of purpose and direction, leading to increased productivity and efficiency.\n*   **Enhanced Self-Awareness**: Self-attention enables individuals to understand their strengths, weaknesses, values, and goals, allowing them to make informed decisions and cultivate a stronger sense of self.\n*   **Better Time Management**: By focusing on what's truly important, individuals can optimize their time, reducing stress and increasing overall well-being.\n*   **Increased Self-Motivation**: Self-attention fosters a growth mindset, encouraging individuals to set and achieve goals, develop resilience, and build confidence.\n*   **Improved Relationships**: When individuals prioritize self-attention, they become more empathetic, compassionate, and authentic, leading to stronger, more meaningful relationships.\n*   **Reduced Distractions**: By being more mindful and present, individuals can minimize distractions, stay focused on their goals, and achieve a better work-life balance.",
#   '### Practical Ways to Cultivate Self-Attention\n\nCultivating self-attention requires intentional practice and a willingness to quiet the mind. Here are some practical tips and techniques to help you develop greater self-awareness and attention:\n\n#### Meditation and Mindfulness\n* Start with short meditation sessions (5-10 minutes) and gradually increase the duration as you become more comfortable with the practice.\n* Focus on your breath, body sensations, or a mantra to calm the mind and bring attention inward.\n* Practice mindfulness in daily activities, such as eating or walking, to cultivate present-moment awareness.\n\n#### Journaling and Reflection\n* Set aside time each day to reflect on your thoughts, emotions, and experiences.\n* Write down your insights, gratitudes, and areas for improvement to process your emotions and gain clarity.\n* Review your journal entries regularly to identify patterns and areas for growth.\n\n#### Prioritizing Sleep and Self-Care\n* Establish a consistent sleep schedule and create a relaxing bedtime routine to improve sleep quality.\n* Engage in regular exercise, yoga, or other physical activities to promote physical and mental well-being.\n* Make time for activities that bring you joy and help you relax, such as reading, listening to music, or spending time in nature.\n\n#### Setting Boundaries and Prioritizing Time\n* Learn to say "no" to non-essential commitments and prioritize your time and energy.\n* Schedule time for self-reflection, relaxation, and activities that nourish your mind, body, and soul.\n* Use tools like calendars, to-do lists, or apps to stay organized and focused.\n\n#### Seeking Feedback and Support\n* Surround yourself with people who support and encourage your personal growth.\n* Seek feedback from trusted friends, family, or mentors to gain new insights and perspectives.\n* Be open to constructive criticism and use it as an opportunity for growth and self-improvement.\n\nBy incorporating these practical tips and techniques into your daily life, you can cultivate greater self-attention and unlock your full potential. Remember, self-attention is a muscle that must be exercised regularly to see results. Be patient, consistent, and compassionate with yourself as you navigate this journey of self-discovery and growth.',
#   '### Common Obstacles to Self-Attention\n\nSelf-attention is a powerful tool for unlocking your full potential, but it\'s not without its challenges. There are several common obstacles that can get in the way of cultivating self-attention, and being aware of them is the first step to overcoming them.\n\n#### 1. Distractions\n\nIn today\'s world, distractions are everywhere. Social media, email, phone notifications, and other digital temptations can easily derail your focus and attention. To overcome this obstacle, try implementing a "no distractions" policy during your self-attention practice. Turn off your phone, log out of social media, and find a quiet, distraction-free space to focus.\n\n#### 2. Fear and Self-Doubt\n\nFear and self-doubt can hold you back from cultivating self-attention, making you feel like you\'re not good enough or that you\'re not worthy of attention. To overcome this, try to reframe your thinking. Remind yourself that self-attention is not about self-aggrandizement, but about cultivating awareness and understanding. Practice self-compassion and remind yourself that it\'s okay to make mistakes.\n\n#### 3. Lack of Time and Energy\n\nLife gets busy, and it can be hard to find time and energy for self-attention. To overcome this obstacle, try to start small. Begin with short, 5-10 minute practice sessions and gradually increase the time as you build your habit. Also, try to prioritize self-attention as a non-negotiable part of your daily routine, just like brushing your teeth or taking a shower.\n\n#### 4. Perfectionism\n\nPerfectionism can be a major obstacle to self-attention, as it can make you feel like you\'re not good enough or that your practice is not perfect. To overcome this, try to let go of your need for perfection. Remember that self-attention is a practice, not a performance. It\'s okay to make mistakes and have off days – it\'s all part of the process.\n\n#### 5. Comparison to Others\n\nFinally, comparing yourself to others can be a major obstacle to self-attention. Try to remember that everyone\'s journey is unique, and comparisons are unfair to yourself and others. Focus on your own growth and progress, and celebrate the successes of others.',
#   "### Conclusion\n\nAs we've explored throughout this article, self-attention is a powerful tool that allows us to tap into our inner strength, overcome self-doubt, and unlock our full potential. By cultivating self-attention, we can break free from distractions, focus on what truly matters, and live a more intentional, meaningful life.\n\nWe encourage you to make self-attention a regular practice, setting aside dedicated time each day to quiet your mind, listen to your heart, and connect with your true self. Remember, self-attention is not a luxury, but a necessity for living a life that truly reflects your values, passions, and dreams.\n\nAs you embark on this journey, remember to be patient, kind, and compassionate with yourself. Self-attention is a practice that requires time, effort, and dedication, but the rewards are well worth it. By committing to self-attention, you'll unlock a deeper sense of purpose, fulfillment, and joy, and live a life that truly reflects your highest potential.",
#   "### Call to Action\n\nNow that you've learned about the power of self-attention, we want to hear from you! Share your experiences and tips on how self-attention has impacted your life. Have you found a new hobby or interest that helps you stay focused? Do you have a daily routine that helps you stay mindful and present? Let us know in the comments below!\n\n**Share Your Story**\n\n* Leave a comment below with your experience or tip on self-attention.\n* Share a personal anecdote or story about how self-attention has helped you.\n* Use the hashtag #SelfAttention so we can track the conversation.\n\nLet's build a community around self-attention and support each other in unlocking our full potential!",
#   "## The Power of Self-Attention: Cultivating Awareness and Mindfulness\n\n### Introduction\nIn today's fast-paced world, we often find ourselves lost in a sea of distractions, struggling to stay present and focused. Amidst the chaos, it's easy to neglect the most essential relationship we have – the one with ourselves. Self-attention, the ability to focus on our own thoughts, emotions, and experiences, is a vital skill that can transform our lives. By cultivating self-attention, we can break free from the constraints of our conditioned habits, tap into our inner wisdom, and live more authentically. In this blog, we'll explore the concept of self-attention, its significance, and practical ways to cultivate it in our daily lives.",
#   '### What is Self-Attention?\n\nSelf-attention is the ability to direct our awareness inward, focusing on our internal experiences, thoughts, and emotions. It involves cultivating a non-judgmental and compassionate understanding of ourselves, allowing us to develop a deeper sense of self-awareness and introspection. By practicing self-attention, we can learn to observe our thoughts, emotions, and physical sensations without becoming identified with them, thereby increasing our capacity for mindfulness and inner peace.',
#   '### Benefits of Self-Attention\n\nCultivating self-attention can have a profound impact on various aspects of our lives. Some of the key benefits include:\n\n*   **Reduced stress and anxiety**: By being more aware of our thoughts and emotions, we can better manage stress and anxiety, leading to a more peaceful and calm state of being.\n*   **Improved relationships**: Self-attention helps us become more empathetic and understanding, allowing us to form deeper and more meaningful connections with others.\n*   **Increased productivity**: By focusing on the present moment and being more aware of our thoughts and actions, we can become more efficient and effective in our daily tasks and goals.\n*   **Enhanced creativity**: Self-attention allows us to tap into our inner source of inspiration, leading to new ideas and perspectives that can help us grow both personally and professionally.\n*   **Better decision-making**: By being more aware of our thoughts, emotions, and values, we can make more informed and intentional decisions that align with our goals and values.',
#   '### Practical Tips for Cultivating Self-Attention\n\nCultivating self-attention is a powerful practice that can bring numerous benefits to our lives. Here are some practical tips and techniques to help you cultivate self-attention:\n\n#### Meditation\n\n*   Start with a daily meditation practice, even if it\'s just 5-10 minutes a day\n*   Focus on your breath, a mantra, or a physical sensation in your body\n*   Be gentle with yourself and acknowledge any thoughts or emotions that arise\n\n#### Journaling\n\n*   Set aside time each day to write down your thoughts, feelings, and experiences\n*   Reflect on your journal entries to identify patterns and areas for growth\n*   Use journaling as a tool for self-reflection and exploration\n\n#### Self-Reflection\n\n*   Schedule regular self-reflection sessions, such as weekly or monthly check-ins\n*   Ask yourself questions like "What am I grateful for?" or "What can I improve on?"\n*   Be honest with yourself and celebrate your accomplishments and progress',
#   '### Overcoming Obstacles and Challenges\n\nCultivating self-attention can be a challenging and often frustrating process, especially for those who are new to mindfulness practices. It\'s common to encounter obstacles and setbacks, but these can also serve as opportunities for growth and learning. Here are some common challenges that may arise and tips on how to overcome them:\n\n#### Resistance to Stillness\n\nOne of the biggest hurdles to cultivating self-attention is resistance to stillness. Many of us are accustomed to a fast-paced, constantly stimulated environment, and the idea of sitting quietly with ourselves can be daunting. To overcome this resistance, try starting small. Begin with short periods of stillness, such as 5-10 minutes, and gradually increase the duration as you become more comfortable with the practice.\n\n#### Difficulty Quieting the Mind\n\nAnother challenge that many people face is difficulty quieting the mind. Our thoughts can be like a runaway train, jumping from one topic to another with ease. To calm the mind, try focusing on your breath, a mantra, or a physical sensation in the body. When the mind wanders, gently acknowledge the thought and return to your chosen focus.\n\n#### Self-Criticism and Judgment\n\nSelf-attention can also be hindered by self-criticism and judgment. We may be too hard on ourselves, thinking that we\'re not doing it "right" or that we\'re not good enough. To overcome this, practice self-compassion. Treat yourself with kindness and understanding, just as you would a close friend.\n\n#### Lack of Motivation\n\nFinally, a lack of motivation can be a significant obstacle to cultivating self-attention. To overcome this, remind yourself of the benefits of self-attention, such as increased self-awareness, reduced stress, and improved relationships. Find a quiet and comfortable space to practice, and make it a non-negotiable part of your daily routine.\n\nBy recognizing and addressing these common challenges, you can overcome obstacles and continue to cultivate self-attention, leading to greater awareness, mindfulness, and a deeper understanding of yourself.',
#   "### Conclusion\n\nAs we've explored the concept of self-attention and its numerous benefits, it's clear that cultivating this awareness and mindfulness is essential for living a more intentional, compassionate, and fulfilling life. By making self-attention a priority, you'll be better equipped to navigate life's challenges, deepen your relationships, and unlock your full potential.",
#   "## Introduction\n\nNestled in the heart of Japan, Mokobara is a small yet captivating town that has been shrouded in mystery for centuries. This hidden gem is steeped in history and cultural significance, offering a unique glimpse into Japan's rich heritage. From its picturesque landscapes to its traditional architecture, Mokobara is a destination that is sure to captivate even the most seasoned traveler. In this blog, we will embark on a journey to uncover the secrets of Mokobara, exploring its significance in Japanese culture and uncovering the stories that lie behind its enchanting allure.",
#   '### History of Mokobara\n\nMokobara, also known as Japanese rice cake, has a rich and storied history that dates back centuries. Its origins are shrouded in mystery, but it is believed to have originated in the Heian period (794-1185 CE). Initially, mokobara was a staple food made from rice flour, water, and salt, served as a simple meal for the working class.\n\nOver time, mokobara evolved and became an integral part of Japanese cuisine. Its popularity spread throughout the country, with various regions developing their unique recipes and techniques. In the Edo period (1603-1867 CE), mokobara became a popular snack among the samurai class, who appreciated its simplicity and nutritional value.\n\nIn the late 19th century, mokobara underwent a significant transformation with the introduction of new ingredients and production methods. Rice flour was replaced with wheat flour, and sugar was added to give mokobara a sweeter taste. This modernization of mokobara led to its widespread adoption across Japan, making it a beloved snack among people of all ages.\n\nToday, mokobara remains a cherished part of Japanese culture, with its impact extending beyond the culinary realm. It has become an integral part of festivals, ceremonies, and social gatherings, symbolizing community, tradition, and hospitality. As we delve deeper into the secrets of mokobara, we will uncover its significance in Japanese society and explore its enduring appeal.',
#   "### Cultural Significance of Mokobara\n\nMokobara, a small town nestled in the mountains of Japan, holds a special place in the country's cultural heritage. The town is woven into various Japanese traditions, customs, and celebrations, making it a fascinating destination for those interested in exploring the country's rich cultural history.\n\n#### Traditional Festivals\n\nMokobara is famous for its traditional festivals, which are an integral part of Japanese culture. The town hosts several festivals throughout the year, each with its unique flavor and significance. The most popular of these festivals is the Mokobara Festival, which is celebrated with great enthusiasm and fervor. The festival features traditional music, dance, and food, showcasing the town's rich cultural heritage.\n\n#### Spiritual Significance\n\nMokobara is also steeped in spiritual significance, with several temples and shrines scattered throughout the town. The town's temples and shrines are revered for their beautiful architecture, serene surroundings, and spiritual significance. Visitors can explore these temples and shrines to gain a deeper understanding of Japanese spirituality and culture.\n\n#### Traditional Crafts\n\nMokobara is also known for its traditional crafts, which have been passed down through generations. The town is famous for its woodcarvings, pottery, and textiles, each with its unique technique and significance. Visitors can witness artisans at work, creating these beautiful crafts, and even purchase them as souvenirs.\n\n#### Family Traditions\n\nMokobara is also a place where family traditions and customs are deeply ingrained. The town's residents take great pride in their heritage, and visitors can experience the warmth and hospitality of Japanese culture firsthand. From traditional cooking to family gatherings, Mokobara is a town that embodies the values of respect, loyalty, and honor that are at the heart of Japanese culture.",
#   "### Mokobara in Modern Times\n\nAs Mokobara continues to fascinate visitors with its unique blend of history and natural beauty, efforts are being made to preserve its rich cultural heritage for future generations. The local community, in collaboration with the Japanese government, has implemented various initiatives to protect and restore the area's historical sites, traditional architecture, and natural environment.\n\nThe preservation of Mokobara's unique character is also reflected in the way the local people pass down their traditions and stories to their children. Elders share tales of the area's history and myths, while young people are encouraged to learn traditional crafts and skills. This intergenerational transmission of knowledge and culture helps to ensure that the essence of Mokobara remains alive and vibrant.\n\nIn addition, modern technology is being used to promote Mokobara's preservation and accessibility. Digital platforms and social media are being used to raise awareness about the area's cultural significance, while innovative tourism initiatives are being developed to minimize the impact of visitor numbers on the environment.\n\nAs a result of these efforts, Mokobara continues to thrive as a cultural and natural gem, not only for the Japanese people but also for visitors from around the world. Its preservation is a testament to the power of community-driven initiatives and the importance of protecting our cultural heritage for future generations.",
# ...
#   "## Common Mistakes: Understanding Self-Attention\n\n### Small Embedding Size: Underutilization of Attention Weights\n\nUsing a small embedding size can lead to underutilization of attention weights. This is because the attention weights are calculated as a dot product between the query and key vectors, which are typically of the same size as the embedding size. If the embedding size is too small, the attention weights will not be able to capture the full range of possible relationships between the input tokens, resulting in a loss of information.\n\n### Padding and Positional Encoding: Don't Neglect Them\n\nPadding and positional encoding are crucial components of self-attention. Padding tokens are used to indicate the start and end of sequences, while positional encoding is used to preserve the order of tokens in the input sequence. If these components are not properly handled, the self-attention mechanism can produce incorrect results.\n\n*   For example, if the input sequence has a length of 10, and the padding token is represented as a vector of zeros, the self-attention weights will be all zeros for the padded tokens. To prevent this, you can use masking to set the attention weights for padded tokens to zero.\n*   Another example is when using positional encoding, if the sequence has a length of 10, the positional encoding vector will be of size 10. If the embedding size is smaller than 10, the positional encoding will be truncated, resulting in a loss of information.\n\n### Masking: A Solution to Prevent Attention on Padding Tokens\n\nTo prevent attention on padding tokens, you can use masking. Masking involves setting the attention weights for padded tokens to zero. Here's an example of how to use masking in a self-attention layer:\n\n```python\nimport torch\nimport torch.nn as nn\n\nclass SelfAttention(nn.Module):\n    def __init__(self, embedding_size):\n        super(SelfAttention, self).__init__()\n        self.query_linear = nn.Linear(embedding_size, embedding_size)\n        self.key_linear = nn.Linear(embedding_size, embedding_size)\n        self.value_linear = nn.Linear(embedding_size, embedding_size)\n        self.mask = nn.Parameter(torch.zeros(1, 1, 1))\n\n    def forward(self, x):\n        query = self.query_linear(x)\n        key = self.key_linear(x)\n        value = self.value_linear(x)\n        attention_weights = torch.matmul(query, key.transpose(-2, -1)) / math.sqrt(self.embedding_size)\n        attention_weights = attention_weights * self.mask\n        return torch.matmul(attention_weights, value)\n```\n\nIn this example, the `mask` parameter is a tensor of size `(1, 1, 1)` that is used to set the attention weights for padded tokens to zero. The `forward` method calculates the attention weights by taking the dot product of the query and key vectors, and then multiplying the result by the mask. The `mask` is applied to the attention weights to prevent attention on padded tokens.",
#   "## Multi-Head Attention\n\nMulti-head attention is a technique used in transformer architectures to improve the model's representational capacity and adaptability. It allows the model to attend to different parts of the input sequence in parallel, capturing a range of contextual dependencies.\n\n### Computing Multi-Head Attention\n\nTo compute multi-head attention, we use multiple attention mechanisms in parallel. Here's a code snippet in PyTorch that demonstrates how to compute multi-head attention:\n```python\nimport torch\nimport torch.nn as nn\n\nclass MultiHeadAttention(nn.Module):\n    def __init__(self, num_heads, hidden_dim):\n        super(MultiHeadAttention, self).__init__()\n        self.num_heads = num_heads\n        self.hidden_dim = hidden_dim\n        self.query_linear = nn.Linear(hidden_dim, hidden_dim)\n        self.key_linear = nn.Linear(hidden_dim, hidden_dim)\n        self.value_linear = nn.Linear(hidden_dim, hidden_dim)\n        self.output_linear = nn.Linear(hidden_dim, hidden_dim)\n\n    def forward(self, query, key, value):\n        # Compute query, key, and value representations\n        query = self.query_linear(query)\n        key = self.key_linear(key)\n        value = self.value_linear(value)\n\n        # Compute attention weights\n        attention_weights = torch.matmul(query, key.transpose(-1, -2)) / math.sqrt(self.hidden_dim)\n\n        # Compute multi-head attention\n        attention_weights = torch.split(attention_weights, self.num_heads, dim=-1)\n        attention_weights = [torch.softmax(aw, dim=-1) for aw in attention_weights]\n        attention_weights = torch.cat(attention_weights, dim=-1)\n\n        # Compute output\n        output = torch.matmul(attention_weights, value)\n        output = self.output_linear(output)\n\n        return output\n```\n### Improving Representational Capacity and Adaptability\n\nMulti-head attention improves representational capacity and adaptability by allowing the model to attend to different parts of the input sequence in parallel. This enables the model to capture a range of contextual dependencies, including local and global dependencies.\n\n### Hyperparameter Tuning\n\nHyperparameter tuning is crucial for multi-head attention. The number of attention heads (num_heads) and the hidden dimension (hidden_dim) need to be carefully tuned for the specific task at hand. Increasing the number of attention heads can improve representational capacity, but it also increases the computational cost. Conversely, decreasing the hidden dimension can reduce the computational cost, but it may also reduce the model's ability to capture contextual dependencies.",
#   '## Edge Cases and Failure Modes\n\nWhen working with self-attention in transformer architectures, it\'s essential to consider edge cases and failure modes that can arise during training and inference.\n\n### Out-of-Vocabulary Words\n\nOut-of-vocabulary (OOV) words can cause attention weights to go to zero, leading to a degradation in model performance. This occurs because the self-attention mechanism relies on the presence of a word in the vocabulary to compute attention weights. If an OOV word is encountered, the attention weights for that word will be zero, effectively ignoring the token.\n\n### Importance of Vocabulary and Subwording\n\nTo mitigate OOV issues, it\'s crucial to use a vocabulary and subwording techniques. A vocabulary is a set of words that the model has seen during training, and subwording involves breaking down words into subwords or wordpieces. This approach allows the model to generate attention weights for OOV words by breaking them down into their constituent subwords.\n\n### Handling Out-of-Vocabulary Words using Subwording\n\nHere\'s an example of how to handle OOV words using subwording:\n```python\nimport torch\nfrom transformers import AutoTokenizer, AutoModelForSequenceClassification\n\n# Load pre-trained tokenizer and model\ntokenizer = AutoTokenizer.from_pretrained(\'distilbert-base-uncased\')\nmodel = AutoModelForSequenceClassification.from_pretrained(\'distilbert-base-uncased\')\n\n# Input text with OOV word\ntext = "This is a sentence with an OOV word."\n\n# Tokenize text using subwording\ninputs = tokenizer.encode_plus(\n    text,\n    add_special_tokens=True,\n    max_length=512,\n    return_attention_mask=True,\n    return_tensors=\'pt\'\n)\n\n# Generate attention weights for OOV word\nattention_weights = model(inputs[\'input_ids\'], attention_mask=inputs[\'attention_mask\'])[0]\n\n# Print attention weights for OOV word\nprint(attention_weights[:, -1, :])  # Last token is the OOV word\n```\nIn this example, the `tokenizer` breaks down the OOV word into its constituent subwords, allowing the model to generate attention weights for each subword. The attention weights for the OOV word can be accessed by looking at the last token in the input sequence.',
#   "## Implementation and Testing\n\n### Implementing Self-Attention in PyTorch\n\nTo implement self-attention in PyTorch, you can use the following code snippet:\n```python\nimport torch\nimport torch.nn as nn\nimport torch.nn.functional as F\n\nclass SelfAttention(nn.Module):\n    def __init__(self, embed_dim, num_heads):\n        super(SelfAttention, self).__init__()\n        self.embed_dim = embed_dim\n        self.num_heads = num_heads\n        self.query_key_value = nn.Linear(embed_dim, 3 * embed_dim)\n\n    def forward(self, x):\n        query, key, value = self.query_key_value(x).chunk(3, dim=-1)\n        attention_weights = F.softmax(torch.matmul(query, key.transpose(-2, -1)) / math.sqrt(self.embed_dim), dim=-1)\n        return torch.matmul(attention_weights, value)\n```\nThis code defines a `SelfAttention` class that takes in the input `x` and outputs the weighted sum of the values.\n\n### Measuring and Visualizing Attention Weights\n\nTo measure and visualize attention weights, you can use a library like `matplotlib` or `seaborn`. For example:\n```python\nimport matplotlib.pyplot as plt\n\n# Get attention weights\nattention_weights = self.self_attention(x)\n\n# Plot attention weights\nplt.imshow(attention_weights.detach().numpy(), cmap='hot', interpolation='nearest')\nplt.show()\n```\nThis will display a heatmap of the attention weights, showing which parts of the input are most relevant.\n\n### Using a Metrics Library for Evaluation and Monitoring\n\nWhen implementing self-attention, it's essential to use a metrics library for evaluation and monitoring. This will help you track your model's performance over time and identify areas for improvement. Some popular metrics libraries include ` tensorboard`, `wandb`, and `tensorboardX`. For example:\n```python\nfrom tensorboardX import SummaryWriter\n\n# Initialize writer\nwriter = SummaryWriter(log_dir='./logs')\n\n# Log attention weights\nwriter.add_histogram('attention_weights', attention_weights, 0)\n\n# Close writer\nwriter.close()\n```\nThis will log the attention weights to TensorBoard, allowing you to visualize and monitor their distribution.\n\nNote: The above code snippets are minimal and serve only to illustrate the concept. You may need to modify them to suit your specific use case.",
#   '## Conclusion and Next Steps\n\nIn this guide, we\'ve demystified self-attention, a crucial component of transformers that enables parallelization of sequence processing. Here\'s a summary of the key takeaways:\n\n* **Key Components and Benefits**: Self-attention relies on three primary components: query, key, and value vectors. The benefits include improved parallelization, ability to capture long-range dependencies, and the possibility to weigh each input equally.\n* **Importance of Continued Research and Experimentation**: While self-attention has been successful in various NLP tasks, there is still much to be explored in terms of its limitations, biases, and potential improvements. Ongoing research and experimentation are necessary to push the boundaries of transformer models.\n* **Resources for Further Learning and Implementation**: For those looking to implement self-attention in their own projects, we recommend exploring the following resources:\n\t+ PyTorch\'s implementation of self-attention: [torch.nn.MultiHeadAttention](https://pytorch.org/docs/stable/nn.html#torch.nn.MultiHeadAttention)\n\t+ Hugging Face\'s Transformers library, which includes a range of self-attention-based models: [Transformers Library](https://huggingface.co/docs/transformers/index)\n\t+ Research papers on self-attention, such as "Attention is All You Need" by Vaswani et al.: [arXiv:1706.03762](https://arxiv.org/abs/1706.03762)'],
#  'final': '# Demystifying Self-Attention: A Technical Guide to Implementing Transformers\n\n## Introduction to Self-Attention\nIn this blog post, we will explore the concept of self-attention and its significance in personal growth and development. We will discuss how self-attention can help individuals focus on their goals, improve their productivity, and enhance their overall well-being.\n\n### Understanding Self-Attention\n==============================\n\nSelf-attention is often misunderstood as being synonymous with self-regulation and self-awareness. However, while these concepts are interconnected, they each have distinct meanings and functions.\n\nSelf-awareness is the ability to have an accurate perception of oneself, including one\'s strengths, weaknesses, and emotions. Self-regulation, on the other hand, is the ability to control and regulate one\'s thoughts, feelings, and behaviors.\n\nSelf-attention, in contrast, is the act of focusing one\'s attention inward, on the self. It involves turning the spotlight of awareness onto one\'s internal experiences, thoughts, and emotions, without judgment or attachment. By cultivating self-attention, individuals can develop a greater understanding of themselves, including their motivations, desires, and values. This increased self-awareness can lead to greater personal growth, as individuals are better equipped to make intentional choices that align with their goals and values.\n\n### Benefits of Self-Attention\n\nSelf-attention has numerous benefits for individuals, including:\n\n*   **Improved Focus**: By directing your attention inward, you can quiet the mind and develop a greater sense of clarity and purpose. This clarity enables you to focus on what\'s truly important and make decisions that align with your values.\n*   **Increased Productivity**: When you cultivate self-attention, you become more aware of your thoughts, emotions, and behaviors. This increased awareness allows you to identify areas where you can optimize your time and energy, leading to greater productivity and efficiency.\n*   **Enhanced Creativity**: Self-attention can help you tap into your inner source of creativity. By quieting the mind and accessing your inner wisdom, you can generate new ideas, solve problems, and approach challenges with a fresh perspective.\n*   **More Positive and Resilient Mindset**: Self-attention allows you to develop a greater sense of self-awareness and self-acceptance. This leads to a more positive and resilient mindset, enabling you to better handle challenges and maintain a sense of calm and well-being in the face of adversity.\n\n### Techniques for Cultivating Self-Attention\n\nDeveloping self-attention is a skill that can be cultivated through various techniques. Here are a few practical methods to help you tap into your inner awareness:\n\n#### Mindfulness\n\n*   Practice mindfulness meditation by focusing on your breath, body sensations, or sensory experiences.\n*   Engage in mindfulness exercises, such as walking or eating, to cultivate present-moment awareness.\n*   Pay attention to your thoughts, emotions, and physical sensations without judgment.\n\n#### Journaling\n\n*   Set aside time each day to reflect on your experiences, thoughts, and emotions.\n*   Write down your goals, aspirations, and intentions to clarify your priorities.\n*   Regularly review your journal entries to track progress and identify areas for improvement.\n\n#### Intention Setting\n\n*   Establish clear, specific, and achievable goals for yourself.\n*   Focus on one goal at a time, breaking it down into smaller, manageable steps.\n*   Regularly review and adjust your goals to ensure they align with your values and priorities.\n\nBy incorporating these techniques into your daily routine, you can cultivate self-attention, unlock your full potential, and achieve your personal goals.\n\n### Overcoming Challenges and Staying Committed\n\nCultivating self-attention requires dedication and perseve ...

# %%
data = app.get_state(config = config)
data
# Out:
# StateSnapshot(values={'topic': 'Write a blog on Self Attention', 'plan': Plan(blog_title='Demystifying Self-Attention: A Technical Guide to Implementing Transformers', audience='NLP developers', tone='Technical', tasks=[Task(id=1, title='Problem Framing and Intuition', goal='Understand the problem and intuition behind self-attention and Transformers', bullets=['Describe the limitations of traditional sequence models (e.g., RNNs, CNNs) and the need for parallelization', 'Explain the key insight behind self-attention: capturing long-range dependencies without sequential processing', 'Highlight the role of multi-head attention in enhancing representational capacity and adaptability'], target_words=150, section_type='intro'), Task(id=2, title='Self-Attention Mechanism', goal='Understand the self-attention mechanism and its components', bullets=['Show a minimal code snippet for computing attention weights using dot-product and softmax', 'Explain why matrix multiplication is used to compute attention weights and query-key similarities', 'Highlight the importance of the scaling factor in the attention mechanism'], target_words=200, section_type='core'), Task(id=3, title='Common Mistakes: Understanding Self-Attention', goal='Learn how to avoid common mistakes when implementing self-attention', bullets=['Explain why using a small embedding size can lead to underutilization of attention weights', 'Highlight the importance of padding and positional encoding in self-attention', 'Show an example of how to use masking to prevent attention on padding tokens'], target_words=250, section_type='common_mistakes'), Task(id=4, title='Multi-Head Attention', goal='Understand the implementation and benefits of multi-head attention', bullets=['Show a code snippet for computing multi-head attention using multiple attention mechanisms', 'Explain how multi-head attention improves representational capacity and adaptability', 'Highlight the importance of hyperparameter tuning for multi-head attention'], target_words=250, section_type='core'), Task(id=5, title='Edge Cases and Failure Modes', goal='Understand how to handle edge cases and failure modes in self-attention', bullets=['Explain why out-of-vocabulary words can cause attention weights to go to zero', 'Highlight the importance of using a vocabulary and subwording', 'Show an example of how to handle out-of-vocabulary words using subwording'], target_words=200, section_type='core'), Task(id=6, title='Implementation and Testing', goal='Understand how to implement and test self-attention in a real-world scenario', bullets=['Show a code snippet for implementing self-attention in PyTorch or TensorFlow', 'Explain how to measure and visualize attention weights for interpretability', 'Highlight the importance of using a metrics library for evaluation and monitoring'], target_words=300, section_type='core'), Task(id=7, title='Conclusion and Next Steps', goal='Summarize key takeaways and provide next steps for implementing self-attention', bullets=['Summarize the key components and benefits of self-attention', 'Highlight the importance of continued research and experimentation', 'Provide resources for further learning and implementation'], target_words=100, section_type='conclusion')]), 'sections': ['## Introduction to Self-Attention\nIn this blog post, we will explore the concept of self-attention and its significance in personal growth and development. We will discuss how self-attention can help individuals focus on their goals, improve their productivity, and enhance their overall well-being.', "### Understanding Self-Attention\n==============================\n\nSelf-attention is often misunderstood as being synonymous with self-regulation and self-awareness. However, while these concepts are interconnected, they each have distinct meanings and functions.\n\nSelf-awareness is the ability to have an accurate perception of oneself, including one's strengths, weaknesses, and emotions. Self-regulation, on the ot ...
